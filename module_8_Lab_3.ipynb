# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohanjyo/FMML-LAB_23B21A4540/blob/main/module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-05-13 15:43:07--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  90.8MB/s    in 0.8s
#
# 2024-05-13 15:43:08 (90.8 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
GaussianNB()
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 3438   1704.04235v1  Domain adaptation is transfer learning which a...    cs
# 22459  1608.00441v1  Nonlinear similarity measures defined in kerne...  stat
# 32408  1612.01356v1  In this paper, we explore the possibility to a...    cs
# 1833   1706.06428v1  Generative models have long been the dominant ...    cs
# 26858  1701.00892v3  In this paper, a hierarchical image matting mo...    cs
# ...             ...                                                ...   ...
# 3493   1709.01779v2  Over the last few years, deep learning has rev...  stat
# 11580  1606.05642v2  Surprise describes a range of phenomena from u...  stat
# 27362  1703.04393v1  With the availability of more powerful compute...    cs
# 36034   1001.4251v1  Many problems can be specified by patterns of ...    cs
# 25680  1511.02407v2  Automated facial identification and facial exp...    cs
#
#                                                    title  year  \
# 3438             Close Yet Distinctive Domain Adaptation  2017
# 22459  Kernel Risk-Sensitive Loss: Definition, Proper...  2016
# 32408    Diagnostic Prediction Using Discomfort Drawings  2016
# 1833   An online sequence-to-sequence model for noisy...  2017
# 26858  A Hierarchical Image Matting Model for Blood V...  2017
# ...                                                  ...   ...
# 3493                           Deep learning from crowds  2017
# 11580  Balancing New Against Old Information: The Rol...  2016
# 27362  Randomized Iterative Reconstruction for Sparse...  2017
# 36034  A Decidable Class of Nested Iterated Schemata ...  2010
# 25680  A Survey of the Trends in Facial and Expressio...  2015
#
#                                                 keywords
# 3438   [adaptation, generalize, different, distributi...
# 22459  [nonlinear, similarity, correntropy, statistic...
# 32408  [possibility, diagnostic, predictions, discomf...
# 1833   [generative, recognition, sophisticated, compl...
# 26858  [hierarchical, specifically, hierarchical, uti...
# ...                                                  ...
# 3493   [revolutionized, dramatically, improving, supe...
# 11580  [describes, phenomena, unexpected, behavioral,...
# 27362  [availability, computers, iterative, reconstru...
# 36034  [specified, propositional, depending, paramete...
# 25680  [automated, identification, expression, recogn...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 3438     [adaptation, generalize, different, distributi...
# 22459    [nonlinear, similarity, correntropy, statistic...
# 32408    [possibility, diagnostic, predictions, discomf...
# 1833     [generative, recognition, sophisticated, compl...
# 26858    [hierarchical, specifically, hierarchical, uti...
#                                ...
# 32981    [importance, applications, distributed, optimi...
# 24050    [convolutional, processing, distinguished, cat...
# 14981    [sentiment, extracted, contributing, semiodisc...
# 24421    [introduces, methodology, resolution, transfor...
# 14250    [theoretic, framework, mitigating, stragglers,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8953 words.
# Out of those 4589 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6242e05f-d4b5-4b35-b873-b11493761c3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6242e05f-d4b5-4b35-b873-b11493761c3a")) {                    Plotly.newPlot(                        "6242e05f-d4b5-4b35-b873-b11493761c3a",                        [{"x":["geometric","smoothness","underlying","probability","generalize","repulsive","minimized","outperforms","classification","distribution","different","discriminative","extensive","maximizes","dependent","consistency","adaptation","consistently","experiments","distances","propagation","structure","significant","conducted","representation","comprehensive","constraints","interesting","distributions","properties","discrepancy","generates","distinctive","conditional","importantly","especially","counterparts","processing","efficient","important","algorithm","sensitive","confirmed","application","similarity","potentially","definition","robustness","nonlinear","correntropy","improvement","convergence","investigate","filtering","simulation","maintaining","theoretical","statistics","performance","experimental","discomfort","multimodal","possibility","intuitive","personnel","factorized","physicians","collected","effective","indicates","prediction","decisions","potential","predictions","diagnostic","reasonable","available","recognition","highlights","beginning","producing","assumption","inference","practitioners","subsequently","practical","instantaneous","complicated","machinery","confident","alternative","transcripts","inherently","sophisticated","contributions","accessible","generative","limitation","introduced","innovations","segmentation","foreground","integrated","specifically","respectively","specified","background","unsupervised","consuming","continuity","hierarchical","computational","complexity","utilizing","automatically","supervised","separates","association","integrate","selecting","regularized","contributing","alongside","simultaneously","regularised","obtaining","computation","collinearity","approaches","estimators","cornerstone","minimisation","exploited","procedure","variables","identifying","developed","modelling","regression","description","associations","observations","including","mathematical","automated","discusses","discussed","authorship","technologies","intelligence","computers","professional","opportunities","understanding","assisting","something","hypothesized","artificial","technology","animation","photography","considers","estimator","stochastic","sufficient","economics","retrieving","restriction","characterizes","abstracts","analyzing","unstructured","necessary","illustrated","consistent","conditions","factorization","parameters","predicting","variational","adversarial","illustrates","transition","embedding","recurrent","simulating","realistic","afterwards","optimized","conditioned","classical","maneuvers","simulator","behaviors","functions","autoencoders","numerical","leveraging","categorical","encountered"],"y":[62,16,126,185,52,1,7,265,490,207,732,90,165,7,77,49,69,48,592,30,71,333,259,59,389,53,137,67,111,203,12,33,9,92,29,121,27,293,386,332,814,70,7,246,136,41,36,110,50,0,148,127,168,71,67,31,152,56,878,369,1,42,32,37,2,4,5,68,266,27,230,64,153,85,17,36,315,383,13,13,25,83,211,16,33,133,6,35,7,6,102,4,20,31,51,16,109,27,146,8,180,18,58,184,80,35,64,141,29,10,91,283,242,45,181,211,6,31,48,39,32,11,3,105,2,35,150,0,421,15,3,3,27,108,144,85,204,51,129,73,16,74,235,60,87,20,49,8,22,97,17,6,15,168,5,7,4,124,46,3,8,40,33,122,67,3,8,11,13,10,55,22,83,16,88,109,28,264,93,58,95,9,39,123,139,9,67,3,58,19,96,2,12,31,238,24,69,42,12,10],"type":"bar"},{"x":["geometric","smoothness","underlying","probability","generalize","repulsive","minimized","outperforms","c ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4589,), (4589, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.82

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 1.0);'>Checkerboard</span> <span style=''>artifact</span> <span style=''>free</span> <span style=''>sub</span> <span style=''>pixel</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style=''>A</span> <span style=''>note</span> <span style=''>on</span> <span style=''>sub</span> <span style=''>pixel</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style=''>resize</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style=''>resize</span> <br/><br/><span style=''>The</span> <span style=''>most</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prominent</span> <span style=''>problem</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>deconvolution</span> <span style=''>layer</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>checkerboard</span> <span style='background-color:rgba(0, 255, 0, 0.6111111111111112);'>artifacts</span> <span style=''>in</span> <span style=''>output</span> <span style=''>images</span> <span style=''>and</span> <span style=''>dense</span> <span style=''>labels</span> <span style=''>To</span> <span style=''>combat</span> <span style=''>this</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3043478260869565);'>smoothness</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>post</span> <span style='background-color:rgba(0, 255, 0, 0.49109414758269726);'>processing</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3071428571428571);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.5902140672782875);'>architecture</span> <span style=''>designs</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>Odena</span> <span style=''>et</span> <span style=''>al</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>highlight</span> <span style=''>three</span> <span style=''>sources</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>checkerboard</span> <span style='background-color:rgba(0, 255, 0, 0.6111111111111112);'>artifacts</span> <span style='background-color:rgba(0, 255, 0, 0.6470588235294117);'>deconvolution</span> <span style=''>overlap</span> <span style=''>random</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>and</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>In</span> <span style=''>this</span> <span style=''>note</span> <span style=''>we</span> <span style=''>proposed</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialization</span> <span style=''>method</span> <span style=''>for</span> <span style=''>sub</span> <span style=''>pixel</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style=''>known</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style=''>NN</span> <span style=''>resize</span> <span style=''>Compared</span> <span style=''>to</span> <span style=''>sub</span> <span style=''>pixel</span> <span style='background-color:rgba(0, 255, 0, 0.523809523809524);'>convolution</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>initialized</span> <span style=''>with</span> <span style=''>schemes</span> <span style=''>designed</span> <span style ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Naive</span> <span style=''>Bayes</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>using</span> <span style=''>censored</span> <span style=''>time</span> <span style=''>to</span> <span style=''>event</span> <span style=''>data</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Predicting</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>individuals</span> <span style=''>risk</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>experiencing</span> <span style=''>a</span> <span style=''>future</span> <span style=''>clinical</span> <span style=''>outcome</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>task</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequences</span> <span style=''>for</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practicing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clinicians</span> <span style=''>and</span> <span style=''>public</span> <span style=''>health</span> <span style=''>experts</span> <span style=''>Modern</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>electronic</span> <span style=''>health</span> <span style=''>records</span> <span style=''>(EHRs)</span> <span style=''>provide</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>alternative</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>longitudinal</span> <span style=''>cohort</span> <span style=''>studies</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditionally</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>construct</span> <span style=''>risk</span> <span style=''>models</span> <span style=''>bringing</span> <span style=''>with</span> <span style=''>them</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>opportunities</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenges</span> <span style=''>Large</span> <span style=''>sample</span> <span style=''>sizes</span> <span style=''>and</span> <span style=''>detailed</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>histories</span> <span style=''>enable</span> <span style=''>the</span> <span style=''>use</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sophisticated</span> <span style=''>machine</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>to</span> <span style=''>uncover</span> <span style=''>complex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associations</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>observational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>databases</span> <span style=''>are</span> <span style=''>often</span> <span style=''>messy</span> <span style=''>with</span> <span style=''>high</span> <span style=''>levels</span> <span style=''>of</span> <span style=''>missing</span> <span style=''>data</span ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>unified</span> <span style=''>view</span> <span style=''>of</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.536231884057971);'>regularized</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.33067729083665337);'>processes</span> <br/><br/><span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.536231884057971);'>regularized</span> <span style=''>average</span> <span style=''>reward</span> <span style='background-color:rgba(0, 255, 0, 0.39080459770114945);'>reinforcement</span> <span style=''>learning</span> <span style=''>in</span> <span style=''>Markov</span> <span style=''>decision</span> <span style='background-color:rgba(255, 0, 0, 0.33067729083665337);'>processes</span> <span style=''>(MDPs)</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extending</span> <span style=''>the</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3485714285714286);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>of</span> <span style=''>policy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>in</span> <span style=''>MDPs</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodate</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>Our</span> <span style=''>key</span> <span style=''>result</span> <span style=''>is</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>using</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>entropy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>joint</span> <span style=''>state</span> <span style=''>action</span> <span style='background-color:rgba(255, 0, 0, 0.3602305475504323);'>distributions</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>dual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>closely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>resembling</span> <span style=''>the</span> <span style=''>Bellman</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimality</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equations</span> <span style=''>This</span> <span style=''>result</span> <span style=''>enables</span> <span style=''>us</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.44);'>formalize</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>entropy</span> <span style='background-color:rgba(255, 0, 0, 0.536231884057971);'>regularized</span> <span style='background-color:rgba(0, 255, 0, 0.39080459770114945);'>reinforcement</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>as</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approximate</span> <span style=''>variants</span> <span style=''>of</span> <span style=''>Mirror</span> <span style=''>Descent</span> <span style=''>or ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Translating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biomarkers</span> <span style=''>between</span> <span style=''>multi</span> <span style=''>way</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <br/><br/><span style='background-color:rgba(255, 0, 0, 0.3);'>Translating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>disease</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biomarkers</span> <span style=''>between</span> <span style=''>multi</span> <span style=''>species</span> <span style=''>omics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>is</span> <span style=''>a</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>direction</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>biomedical</span> <span style=''>research</span> <span style=''>The</span> <span style=''>existing</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>limited</span> <span style=''>to</span> <span style=''>simple</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>setups</span> <span style=''>such</span> <span style=''>as</span> <span style=''>basic</span> <span style=''>healthy</span> <span style=''>diseased</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>comparisons</span> <span style=''>Most</span> <span style=''>of</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>also</span> <span style=''>require</span> <span style=''>an</span> <span style=''>a</span> <span style=''>priori</span> <span style=''>matching</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>(eg</span> <span style=''>genes</span> <span style=''>or</span> <span style=''>metabolites)</span> <span style=''>between</span> <span style=''>the</span> <span style=''>species</span> <span style=''>However</span> <span style=''>many</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>have</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>complicated</span> <span style=''>multi</span> <span style=''>way</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimental</span> <span style=''>design</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>involving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>irregularly</span> <span style=''>sampled</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>measurements</span> <span style=''>and</span> <span style=''>for</span> <span style=''>instance</span> <span style=''>metabolites</span> <span style=''>do</span> <span style=''>not</span> <span style=''>always</span> <span style=''>have</span> <span style=''>known</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>matchings</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>organisms</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>Bayesian</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>modelling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>translating</span> <span style=''>between</span> <span style=''>multiple</span> <span style=''>species</span> <span style=''>the</span> <span style=''>results</span> <span style=''>from</span> <span style=''>omics</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <s ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.1327338129496403)
# 	segmentation (0.06474820143884892)
# 	knowledge (0.12697841726618705)
# 	processing (0.10539568345323741)
# 	representation (0.13992805755395685)
# 	architecture (0.09352517985611511)
# 	detection (0.1197841726618705)
# 	different (0.2633093525179856)
# 	convolutional (0.12949640287769784)
# 	recognition (0.13776978417266186)
#
# Some Statistics words are:
# 	algorithm (0.3792079207920792)
# 	statistical (0.148019801980198)
# 	stochastic (0.13366336633663367)
# 	estimation (0.16732673267326734)
# 	variables (0.1495049504950495)
# 	theoretical (0.15396039603960396)
# 	distribution (0.18514851485148515)
# 	inference (0.19504950495049506)
# 	dimensional (0.18366336633663366)
# 	regression (0.18316831683168316)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f7370667-ac5f-4f97-ade0-4d211251aac1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f7370667-ac5f-4f97-ade0-4d211251aac1")) {                    Plotly.newPlot(                        "f7370667-ac5f-4f97-ade0-4d211251aac1",                        [{"x":["geometric","smoothness","underlying","probability","generalize","repulsive","minimized","outperforms","classification","distribution","different","discriminative","extensive","maximizes","dependent","consistency","adaptation","consistently","experiments","distances","propagation","structure","significant","conducted","representation","comprehensive","constraints","interesting","distributions","properties","discrepancy","generates","distinctive","conditional","importantly","especially","counterparts","processing","efficient","important","algorithm","sensitive","confirmed","application","similarity","potentially","definition","robustness","nonlinear","correntropy","improvement","convergence","investigate","filtering","simulation","maintaining","theoretical","statistics","performance","experimental","discomfort","multimodal","possibility","intuitive","personnel","factorized","physicians","collected","effective","indicates","prediction","decisions","potential","predictions","diagnostic","reasonable","available","recognition","highlights","beginning","producing","assumption","inference","practitioners","subsequently","practical","instantaneous","complicated","machinery","confident","alternative","transcripts","inherently","sophisticated","contributions","accessible","generative","limitation","introduced","innovations","segmentation","foreground","integrated","specifically","respectively","specified","background","unsupervised","consuming","continuity","hierarchical","computational","complexity","utilizing","automatically","supervised","separates","association","integrate","selecting","regularized","contributing","alongside","simultaneously","regularised","obtaining","computation","collinearity","approaches","estimators","cornerstone","minimisation","exploited","procedure","variables","identifying","developed","modelling","regression","description","associations","observations","including","mathematical","automated","discusses","discussed","authorship","technologies","intelligence","computers","professional","opportunities","understanding","assisting","something","hypothesized","artificial","technology","animation","photography","considers","estimator","stochastic","sufficient","economics","retrieving","restriction","characterizes","abstracts","analyzing","unstructured","necessary","illustrated","consistent","conditions","factorization","parameters","predicting","variational","adversarial","illustrates","transition","embedding","recurrent","simulating","realistic","afterwards","optimized","conditioned","classical","maneuvers","simulator","behaviors","functions","autoencoders","numerical","leveraging","categorical","encountered","euclidean","applications","clustering","homogeneity","techniques","exploration","routinely","attributes","determines","computationally","implemented","conjugate","implement","algorithms","optimization","principled","connections","optimizer","requirements","continuous","establish","implementation","dimensional","penalized","likelihood","framework","leveraged","rigorously","demonstrate","graphical","selection","contemporary","tremendous","functional","comparison","correlation","proposing","undertake","comparisons","performing","covariance","minimization","literature","estimation","coordinate","intensity","appropriately","processes","inhomogeneous","resulting","dimensions","guaranteeing","attractive","transformed","formulation","tractable","generaliza ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	correntropy
# 	collinearity
# 	homogeneity
# 	representer
# 	changepoint
# 	timestamp
# 	chebyshev
# 	schizophrenia
# 	parametrically
# 	deteriorate
# 	reparameterized
# 	emphstructured
# 	martingale
# 	reparametrization
# 	workloads
# 	workhorse
# 	factoring
# 	discounting
# 	normality
# 	microarrays
# Some words which never appear in Statistics papers:
# 	personnel
# 	authorship
# 	something
# 	animation
# 	photography
# 	maneuvers
# 	traveling
# 	modulates
# 	retrieves
# 	monocular
# 	allowable
# 	memorizing
# 	progressions
# 	inseparable
# 	pragmatics
# 	discourse
# 	presupposition
# 	olfactory
# 	concentric
# 	superintelligent

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.087467967519837e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7791666666666667
